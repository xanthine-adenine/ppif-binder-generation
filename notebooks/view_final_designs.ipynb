# %%
import pandas as pd

from pathlib import Path

RUN_ID = 2602272228
OUT_DIR = Path("../out/")
RUN_DIR = OUT_DIR / f"run_{RUN_ID}"
RUN_DIR
# Out:
# PosixPath('../out/run_2602272228')

# %%
final_design_metrics_csv = pd.read_csv(Path(RUN_DIR) / "final_ranked_designs" / "final_designs_metrics_30.csv")
final_design_metrics_csv.head()
# Out:
#                           id  final_rank designed_sequence  \
# 0  cyclic_peptide_to_ppif_45           1    GKVSKEEGIVSADS
# 1  cyclic_peptide_to_ppif_27           2      ATKETGPRNDSM
# 2  cyclic_peptide_to_ppif_25           3    SGVVDPETGIVDSD
# 3  cyclic_peptide_to_ppif_36           4          GAEPSNTP
# 4  cyclic_peptide_to_ppif_03           5          SGLTPSNS
#
#   designed_chain_sequence  num_design  design_to_target_iptm  \
# 0          GKVSKEEGIVSADS          14                0.57934
# 1            ATKETGPRNDSM          12                0.62254
# 2          SGVVDPETGIVDSD          14                0.45685
# 3                GAEPSNTP           8                0.44213
# 4                SGLTPSNS           8                0.43143
#
#    min_design_to_target_pae  design_ptm  filter_rmsd  plip_hbonds_refolded  \
# 0                   4.40262     0.82379      0.33533                     5
# 1                   3.49454     0.80973      0.39142                     2
# ...
